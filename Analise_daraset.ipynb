# %% [markdown]
# # Carregando bibliotecas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Configurando Bibliotecas

# %%
# Configurando o matplotlib
plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 11
plt.style.use('seaborn-v0_8')
#

# %% [markdown]
# # Analise dos Dados

# %% [markdown]
# ## Abrindo Dataset

# %% [markdown]
# ### Analise da Estrutura e qualidade dos dados

# %%
# Definino o caminho do arquivo
dataset_path = r"dataset\heart_disease_risk_2026.csv"

# %%
data = pd.read_csv(dataset_path, sep= ",")
data.head(15)
# Out:
#     patient_id  age     sex  resting_bp_systolic  resting_bp_diastolic  \
# 0            1   44    Male                  117                    74
# 1            2   57    Male                  139                    94
# 2            3   29    Male                  128                    78
# 3            4   72    Male                  132                    86
# 4            5   62  Female                  116                    75
# 5            6   50  Female                  122                    71
# 6            7   50  Female                  133                    85
# 7            8   58  Female                  133                    81
# 8            9   51  Female                  121                    64
# 9           10   51    Male                  126                    77
# 10          11   63  Female                  123                    87
# 11          12   61  Female                  112                    77
# 12          13   53  Female                  110                    81
# 13          14   53    Male                  131                    70
# 14          15   56  Female                  148                    92
#
#     cholesterol_total  hdl  ldl  triglycerides  fasting_blood_sugar  ...  \
# 0                 193   57  106            119                  112  ...
# 1                 185   69  110             35                  114  ...
# 2                 197   52  108            157                   95  ...
# 3                 197   59  104            143                   92  ...
# 4                 154   65   75            104                  135  ...
# 5                 147   46  101             41                  134  ...
# 6                 227   63  124            194                  109  ...
# 7                 141   54   99             40                  118  ...
# 8                 219   84  104             85                  136  ...
# 9                 172   50  104            115                  132  ...
# 10                164   65   81            136                  170  ...
# 11                230   65  148            105                  101  ...
# 12                166   52  104            149                  103  ...
# 13                192   63   92            127                  107  ...
# 14                177   41  107            102                   78  ...
#
#     family_history  smoker_status  alcohol_units_per_week  \
# 0            False          Never                     2.9
# 1            False          Never                     3.0
# 2            False        Current                     3.5
# 3            False          Never                     2.7
# 4             True         Former                     3.3
# 5             True         Former                     3.3
# 6            False          Never                     5.1
# 7             True        Current                     2.5
# 8            False         Former                     2.8
# 9             True         Former                     6.1
# 10           False          Never                     4.7
# 11           False          Never                    14.1
# 12           False          Never                     6.8
# 13           False          Never                    14.6
# 14           False          Never                     8.7
#
#     exercise_minutes_per_week sleep_hours  stress_score  wearable_owner  \
# 0                          86         5.4          19.8            True
# 1                         132         4.3          45.8            True
# 2                         128         5.1          17.7            True
# 3                          18         6.8          63.6            True
# 4                          24         8.2          58.7           False
# 5                         190         5.9          55.1           False
# 6                          91         8.2          82.2            True
# 7                          92         6.4          45.5            True
# 8                         266         9.0          65.6            True
# 9                          89         9.1          58.7           False
# 10                        155         7.2          54.0           False
# 11                        197         5.4          32.5            True
# 12                        227         7.6          36.7            True
# 13                         84         5.1          52.1            True
# 14                         70         7.1          51.3            True
#
#     daily_steps diet_quality_score  has_heart_disease
# 0          7731               62.9                  0
# 1          2629               74.6                  1
# 2          9290               65.7                  0
# 3          7373               48.5                  1
# 4          6331               47.3                  1
# 5          6857               82.6                  0
# 6          8466               63.7                  0
# 7          6769               42.4                  1
# 8          7648               53.5                  0
# 9          7531               53.2                  0
# 10         3440               62.7                  1
# 11         6443               80.9                  0
# 12         7583               60.0                  0
# 13         8539               80.2                  0
# 14         4864               64.8                  0
#
# [15 rows x 27 columns]

# %%
#Informações sobre as colunas e linhas

print(f"""Informações sobre a tabela
Linhas: {data.shape[0]} 
colunas: {data.shape[1]} 
""")

data.info()
# Out:
# Informações sobre a tabela
# Linhas: 9000
# colunas: 27
#
# <class 'pandas.DataFrame'>
# RangeIndex: 9000 entries, 0 to 8999
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   patient_id                 9000 non-null   int64
#  1   age                        9000 non-null   int64
#  2   sex                        9000 non-null   str
#  3   resting_bp_systolic        9000 non-null   int64
#  4   resting_bp_diastolic       9000 non-null   int64
#  5   cholesterol_total          9000 non-null   int64
#  6   hdl                        9000 non-null   int64
#  7   ldl                        9000 non-null   int64
#  8   triglycerides              9000 non-null   int64
#  9   fasting_blood_sugar        9000 non-null   int64
#  10  hba1c                      9000 non-null   float64
#  11  bmi                        9000 non-null   float64
#  12  resting_heart_rate         9000 non-null   int64
#  13  max_heart_rate_achieved    9000 non-null   int64
#  14  chest_pain_type            9000 non-null   str
#  15  exercise_induced_angina    9000 non-null   bool
#  16  st_depression              9000 non-null   float64
#  17  family_history             9000 non-null   bool
#  18  smoker_status              9000 non-null   str
#  19  alcohol_units_per_week     9000 non-null   float64
#  20  exercise_minutes_per_week  9000 non-null   int64
#  21  sleep_hours                9000 non-null   float64
#  22  stress_score               9000 non-null   float64
#  23  wearable_owner             9000 non-null   bool
#  24  daily_steps                9000 non-null   int64
#  25  diet_quality_score         9000 non-null   float64
#  26  has_heart_disease          9000 non-null   int64
# dtypes: bool(3), float64(7), int64(14), str(3)
# memory usage: 1.7 MB

# %%
# Estatísticaas descritivas sobre os dados
data.describe(include= "all").T
# Out:
#                             count unique           top  freq         mean  \
# patient_id                 9000.0    NaN           NaN   NaN       4500.5
# age                        9000.0    NaN           NaN   NaN    53.977333
# sex                          9000      2          Male  4731          NaN
# resting_bp_systolic        9000.0    NaN           NaN   NaN   127.849778
# resting_bp_diastolic       9000.0    NaN           NaN   NaN    80.788778
# cholesterol_total          9000.0    NaN           NaN   NaN   188.753556
# hdl                        9000.0    NaN           NaN   NaN    55.215333
# ldl                        9000.0    NaN           NaN   NaN   103.275556
# triglycerides              9000.0    NaN           NaN   NaN      152.045
# fasting_blood_sugar        9000.0    NaN           NaN   NaN   119.470444
# hba1c                      9000.0    NaN           NaN   NaN     5.791633
# bmi                        9000.0    NaN           NaN   NaN    25.264922
# resting_heart_rate         9000.0    NaN           NaN   NaN    80.912667
# max_heart_rate_achieved    9000.0    NaN           NaN   NaN   164.838333
# chest_pain_type              9000      4  Asymptomatic  4265          NaN
# exercise_induced_angina      9000      2         False  6938          NaN
# st_depression              9000.0    NaN           NaN   NaN     1.012911
# family_history               9000      2         False  6548          NaN
# smoker_status                9000      3         Never  4980          NaN
# alcohol_units_per_week     9000.0    NaN           NaN   NaN     5.708733
# exercise_minutes_per_week  9000.0    NaN           NaN   NaN   139.493444
# sleep_hours                9000.0    NaN           NaN   NaN     6.994578
# stress_score               9000.0    NaN           NaN   NaN    47.968033
# wearable_owner               9000      2         False  5015          NaN
# daily_steps                9000.0    NaN           NaN   NaN  6163.659333
# diet_quality_score         9000.0    NaN           NaN   NaN      59.4674
# has_heart_disease          9000.0    NaN           NaN   NaN        0.303
#
#                                    std    min      25%     50%      75%  \
# patient_id                 2598.220545    1.0  2250.75  4500.5  6750.25
# age                          13.008051   18.0     45.0    54.0     63.0
# sex                                NaN    NaN      NaN     NaN      NaN
# resting_bp_systolic          13.767233   85.0    119.0   128.0    137.0
# resting_bp_diastolic         10.939943   50.0     74.0    81.0     88.0
# cholesterol_total            32.271644   90.0    167.0   189.0    211.0
# hdl                            12.3944   18.0     47.0    55.0     64.0
# ldl                          27.342198   35.0     85.0   103.0    122.0
# triglycerides                51.448384   35.0    117.0   151.0    186.0
# fasting_blood_sugar          22.778082   60.0    104.0   119.0    135.0
# hba1c                         0.692645    4.0      5.3     5.8      6.3
# bmi                           4.371525   15.0     22.3    25.3     28.2
# resting_heart_rate            8.604685   48.0     75.0    81.0     87.0
# max_heart_rate_achieved      21.290773   93.0    150.0   166.0    180.0
# chest_pain_type                    NaN    NaN      NaN     NaN      NaN
# exercise_induced_angina            NaN    NaN      NaN     NaN      NaN
# st_depression                  0.95709    0.0      0.4     0.7      1.4
# family_history                     NaN    NaN      NaN     NaN      NaN
# smoker_status                      NaN    NaN      NaN     NaN      NaN
# alcohol_units_per_week        5.070642    0.0      2.2     4.2      7.7
# exercise_minutes_per_week    63.660433    0.0     96.0   139.0    183.0
# sleep_hours                   1.104215    3.1      6.3     7.0      7.7
# stress_score                 16.162484    0.0     37.1    48.1     58.9
# wearable_owner                     NaN    NaN      NaN     NaN      NaN
# daily_steps                2170.685995  500.0   4658.0  6178.0  7632.75
# diet_quality_score           14.476064    4.8     49.7    59.6     69.1
# has_heart_disease             0.459581    0.0      0.0     0.0      1.0
#
#                                max
# patient_id                  9000.0
# age                           90.0
# sex                            NaN
# resting_bp_systolic          181.0
# resting_bp_diastolic         126.0
# cholesterol_total            314.0
# hdl                          110.0
# ldl                          207.0
# triglycerides                390.0
# fasting_blood_sugar          204.0
# hba1c                          8.6
# bmi                           43.3
# resting_heart_rate           111.0
# max_heart_rate_achieved      210.0
# chest_pain_type                NaN
# exercise_induced_angina        NaN
# st_depression                  6.5
# family_history                 NaN
# smoker_status                  NaN
# alcohol_units_per_week        45.9
# exercise_minutes_per_week    366.0
# sleep_hours                   11.0
# stress_score                 100.0
# wearable_owner                 NaN
# daily_steps                13950.0
# diet_quality_score           100.0
# has_heart_disease              1.0

# %%
#Dados Vazios
print("Dados Vazios por Coluna")

print(data.isnull().sum())
print("")
print(f"Total de Dados Vazios: {data.isnull().sum().sum()}")
# Out:
# Dados Vazios por Coluna
# patient_id                   0
# age                          0
# sex                          0
# resting_bp_systolic          0
# resting_bp_diastolic         0
# cholesterol_total            0
# hdl                          0
# ldl                          0
# triglycerides                0
# fasting_blood_sugar          0
# hba1c                        0
# bmi                          0
# resting_heart_rate           0
# max_heart_rate_achieved      0
# chest_pain_type              0
# exercise_induced_angina      0
# st_depression                0
# family_history               0
# smoker_status                0
# alcohol_units_per_week       0
# exercise_minutes_per_week    0
# sleep_hours                  0
# stress_score                 0
# wearable_owner               0
# daily_steps                  0
# diet_quality_score           0
# has_heart_disease            0
# dtype: int64
#
# Total de Dados Vazios: 0

# %% [markdown]
# ## Tratamendo dos Dados

# %% [markdown]
# ### Dados Nulos

# %% [markdown]
# ### Duplicados

# %% [markdown]
# # Analise Estatística

# %%
# Qual a Proporção de pessoas que tiveram Problema?

print(data['has_heart_disease'].map({0:"Não", 1:"Sim"}).value_counts(normalize= True))


data['has_heart_disease'].map({0:"Não", 1:"Sim"}).value_counts(normalize= True).plot(kind= "bar")
# Out:
# has_heart_disease
# Não    0.697
# Sim    0.303
# Name: proportion, dtype: float64
# <Axes: xlabel='has_heart_disease'>

# %%
# faixa etária com maior risco?

faixas_etarias = np.arange(18, 91, 5)

fig, axes = plt.subplots(2, 1, figsize= (10, 10))

ax = axes.flat[0]

data["faixas_etaria"] = pd.cut(data["age"], bins= faixas_etarias)

data_faixas = data.groupby("faixas_etaria", observed= True)["has_heart_disease"].mean()*100

ax.bar(data_faixas.index.astype(str) , data_faixas.values, color = '#C44E52')

# Sexo com maior risco

SEX_COLORS = {"Male": '#4C72B0', "Female": '#DD8452'}
ax = axes.flat[1]

data_sexo = data.groupby("sex")["has_heart_disease"].mean()*100

cores = [SEX_COLORS[i] for i in data_sexo.index]

data_sexo.plot(kind= "bar", ax= ax, color= cores)

plt.tight_layout()

# %%
cores
# Out:
# ['#DD8452', '#4C72B0']

# %%
# Diferença por Caracteristica
clinical_fields = ['resting_bp_systolic','cholesterol_total','ldl','hdl','bmi','hba1c']
DISEASE_COLORS = {0: 'green', 1: 'red'}

fig, axes = plt.subplots(2, 3, figsize = (17, 5))


for i in range(len(clinical_fields)):
    ax = axes.flat[i]
    field = clinical_fields[i]
    title = clinical_fields[i]

    for status, c in DISEASE_COLORS.items():
        ax.hist(data[data.has_heart_disease == status][field], bins= 25, alpha = 0.6, color= c , density= True)
        ax.set_title(title)
plt.suptitle('Clinical Measurement Distributions — Green = No Disease, Red = Has Disease')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Modelo de Classificação

# %% [markdown]
# ## Configuração dos Modelos

# %% [markdown]
# ## Treinamento

# %% [markdown]
# ### Resultados
